# %% [markdown]
# <a href="https://colab.research.google.com/github/NoirNoum/Praktikum-Struktur-Data/blob/main/Pertemuan7_Praktikum_Strukdat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Binary Tree secara manual

# %%
class Node:
  def __init__(self, data):
    self.data = data
    self.left = None
    self.right = None

# Membuat tree secara manual
root = Node(1)
root.left = Node(2)
root.right = Node(3)
root.left.left = Node(4)
root.left.right = Node(5)

# Fungsi inorder traversal
def inorder(node):
  if node:
    inorder(node.left)
    print(node.data, end=' ')
    inorder(node.right)

print("Hasil inorder traversal dari binary tree:")
inorder(root)
# Out:
# Hasil inorder traversal dari binary tree:
# 4 2 5 1 3

# %% [markdown]
# ---
#
# Binary Search Tree

# %%
class Node:
  def __init__(self, data):
    self.data = data
    self.left = None
    self.right = None

class BinarySearchTree:
  def __init__(self):
    self.root = None
  def insert(self, root, data):
    if root is None:
      return Node(data)
    if data < root.data:
      root.left = self.insert(root.left, data)
    else:
      root.right = self.insert(root.right, data)
    return root

bst = BinarySearchTree()
root = None
data_list = [50, 30, 70, 20, 40, 60, 80]
for value in data_list:
  root = bst.insert(root, value)

# %% [markdown]
# ---
#
#
# Traversal pada BST

# %%
def inorder(node):
  if node:
    inorder(node.left)
    print(node.data, end=' ')
    inorder(node.right)

def preorder(node):
  if node:
    print(node.data, end=' ')
    preorder(node.left)
    preorder(node.right)

def postorder(node):
  if node:
    postorder(node.left)
    postorder(node.right)
    print(node.data, end=' ')

print("Inorder Traversal:")
inorder(root)
print("\nPreorder Traversal:")
preorder(root)
print("\nPostorder Traversal:")
postorder(root)

# %% [markdown]
# ---
#
# Pencarian Nilai dalam BST

# %%
def search(node, key):
  if node is None or node.data == key:
    return node
  if key < node.data:
    return search(node.left, key)
    return search(node.right, key)

# Uji pencarian
key = 60
result = search(root, key)
if result:
  print(f"{key} ditemukan dalam tree.")
else:
  print(f"{key} tidak ditemukan.")

key = 25
result = search(root, key)
if result:
  print(f"{key} ditemukan dalam tree.")
else:
  print(f"{key} tidak ditemukan.")
# Out:
# 60 tidak ditemukan.
# 25 tidak ditemukan.

# %% [markdown]
# ---
#
#
# # Tugas / Latihan

# %% [markdown]
# **Tugas 01**

# %% [markdown]
# Data identitas:
#
# * Nama lengkap: Pardede Putra Anjasmara
# * Tanggal lahir: 27 - 05
# * NPM: 2505060061
#
# Perhitungan:
#
# * Jumlah huruf nama (tanpa spasi) = 21
# * Jumlah huruf vokal = 9
# * Tanggal lahir = 27
# * Bulan lahir = 5

# %%
# Struktur Binary Tree berdasarkan identitas

class Node:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

# Membuat tree manual
root = Node(21)         # jumlah huruf nama
root.left = Node(9)     # jumlah huruf vokal
root.right = Node(61)   # dua digit terakhir NPM

# level berikutnya
root.left.left = Node(27)   # tanggal lahir
root.right.right = Node(5)  # bulan lahir


# inorder traversal
def inorder(node):
    if node:
        inorder(node.left)
        print(node.data, end=' ')
        inorder(node.right)

print("Hasil Inorder Traversal:")
inorder(root)
# Out:
# Hasil Inorder Traversal:
# 27 9 21 61 5

# %% [markdown]
# si node:
#
# * Root → jumlah huruf nama
# * Anak kiri → jumlah huruf vokal
# * Anak kanan → dua digit terakhir NPM
# * Node berikutnya → tanggal dan bulan lahir

# %% [markdown]
# ---
#
#
# **TUGAS 02**

# %% [markdown]
# **Data yang Digunakan**
#
# Menggunakan:
# * 3 digit terakhir NPM → 061
# * Tanggal lahir → 27
# * Bulan lahir → 05
#
# ASCII huruf depan nama:
# * P = 80
# * A = 65
#
# Dua angka favorit:
# * 17
# * 4

# %% [markdown]
# Data BST:

# %%
[61, 27, 5, 80, 65, 17, 4]

# %%
# Program Binary Search Tree (BST)

class Node:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None


class BinarySearchTree:
    def insert(self, root, data):

        # jika root kosong
        if root is None:
            return Node(data)

        # jika data lebih kecil
        if data < root.data:
            root.left = self.insert(root.left, data)

        # jika data lebih besar
        else:
            root.right = self.insert(root.right, data)
        return root


# inorder traversal
def inorder(node):
    if node:
        inorder(node.left)
        print(node.data, end=' ')
        inorder(node.right)


# preorder traversal
def preorder(node):
    if node:
        print(node.data, end=' ')
        preorder(node.left)
        preorder(node.right)


# postorder traversal
def postorder(node):
    if node:
        postorder(node.left)
        postorder(node.right)
        print(node.data, end=' ')


# fungsi search
def search(node, key):
    # jika data kosong atau ditemukan
    if node is None or node.data == key:
        return node

    # cari ke kiri
    if key < node.data:
        return search(node.left, key)

    # cari ke kanan
    return search(node.right, key)


# membuat BST
bst = BinarySearchTree()
root = None

# data BST
data_list = [61, 27, 5, 80, 65, 17, 4]

# insert data
for value in data_list:
    root = bst.insert(root, value)

# output traversal
print("Inorder Traversal:")
inorder(root)

print("\nPreorder Traversal:")
preorder(root)

print("\nPostorder Traversal:")
postorder(root)

# pencarian data
print("\n")

key = 61
result = search(root, key)

if result:
    print(f"{key} ditemukan dalam tree.")
else:
    print(f"{key} tidak ditemukan.")

key = 100
result = search(root, key)

if result:
    print(f"{key} ditemukan dalam tree.")
else:
    print(f"{key} tidak ditemukan.")
# Out:
# Inorder Traversal:
# 4 5 17 27 61 65 80
# Preorder Traversal:
# 61 27 5 4 17 80 65
# Postorder Traversal:
# 4 17 5 27 65 80 61
#
# 61 ditemukan dalam tree.
# 100 tidak ditemukan.

# %% [markdown]
# **PENJELASAN SINGKAT**
#
# Program BST bekerja dengan konsep:
#
# * nilai lebih kecil masuk ke kiri
# * nilai lebih besar masuk ke kanan
#
# Traversal digunakan untuk:
#
# * Inorder → menghasilkan data terurut
# * Preorder → membaca struktur tree
# * Postorder → memproses subtree terlebih dahulu
#
# Sedangkan fungsi search digunakan untuk mencari data tertentu di dalam Binary Search Tree secara efisien.
